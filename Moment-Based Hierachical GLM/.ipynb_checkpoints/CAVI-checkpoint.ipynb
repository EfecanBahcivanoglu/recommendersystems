# %%
import pandas as pd
import numpy as np
from scipy.special import digamma
import time
import math
import os

# %%
df1 = pd.read_csv('unique_userid_sample_1.csv')
df1.drop(df1.columns[1:10], axis = 1, inplace = True)
df1.rename(columns = {'count': 'Count', 'group': 'UserId', 'movie_id':'ItemId'}, inplace = True)

# %% [markdown]
# Ensure every user and every item that is in the validation set is also in the training set.Start by shuffling the dataframe to ensure randomness.Create a mask to filter validation set.
# Now let's take the top val_size proportion of this temporary dataframe for validation. Ensure that all users and items in the validation set are also in the training set. Adjust the training set in case any validation rows are left.

# %%
def create_validation_set(df, val_size=0.2):
    
    users = df['UserId'].unique()
    items = df['ItemId'].unique()

   
    mask = df.duplicated(subset=['UserId'], keep=False) & df.duplicated(subset=['ItemId'], keep=False)
    temp_df = df[mask]

    
    val_count = int(len(temp_df) * val_size)
    validation_set = temp_df.head(val_count)
    training_set = pd.concat([df, validation_set]).drop_duplicates(keep=False)

    
    validation_set = validation_set[validation_set['UserId'].isin(training_set['UserId'])]
    validation_set = validation_set[validation_set['ItemId'].isin(training_set['ItemId'])]

    
    training_set = pd.concat([training_set, validation_set]).drop_duplicates(keep=False)

    return training_set, validation_set

# %%
training_set, validation_set = create_validation_set(df1)
(training_set.shape[0], validation_set.shape[0])
interaction_matrix = training_set.pivot_table(index='ItemId', columns='UserId', values='Count', fill_value=0)


values_users = [i for i in range(len(interaction_matrix))]
user_dict = {k:v for (k,v) in zip(interaction_matrix.columns, values_users)}
values_items = [i for i in range(len(interaction_matrix))]
item_dict = {k:v for (k,v) in zip(interaction_matrix.index, values_items)}

y_iu = interaction_matrix.values
y_ui = y_iu.transpose()

# %%
def initiliaze_parameters(num_users, num_items, k, a=0.3, a_prime=0.3, c=0.3, c_prime=0.3, b_prime=1.0, d_prime=1.0):
    
    k_shp = (a_prime + k * a) * np.ones(num_users)
    t_shp = (c_prime + k * c) * np.ones(num_items)
    k_rte = 1 * np.ones(num_users)
    t_rte = 1 * np.ones(num_items)
    
    rng = np.random.default_rng()
    gamma_rte = a_prime + 0.01 * rng.random((num_users, k))
    gamma_shp = a_prime + 0.01 * rng.random((num_users, k))
    lambda_rte = c_prime + 0.01 * rng.random((num_items, k))
    lambda_shp = c_prime + 0.01 * rng.random((num_items, k))
    
    phi = np.empty((num_users, num_items, k))
    
    return gamma_shp, gamma_rte, lambda_shp, lambda_rte, k_shp, k_rte, t_shp, t_rte, phi, a, a_prime, c, c_prime, b_prime, d_prime

# %%
def CAVI_simple(num_users, num_items, k, y_ui, gamma_shp, gamma_rte, lambda_shp, lambda_rte, k_shp, k_rte, t_shp, t_rte, phi):
    

    # Now we will update phi_uik with both shape and rate parameters inside the loop
    for u in range(num_users):
        #print(u) if u %100 == 0 else None
        for i in range(num_items):
            if y_ui[u, i] > 0:
                l = np.zeros(5)
                for d in range(k):
                    exponent = (digamma(gamma_shp[u,d]) - np.log(gamma_rte[u,d]) +
                            digamma(lambda_shp[i,d]) - np.log(lambda_rte[i,d]))
                    l[d] = exponent

                #print(l / np.sum(l))
                #print(np.exp(l) / np.sum(np.exp(l)))
                #print(np.sum(l))
                # Exponentiate and normalize phi_uik so that it sums to 1 over k for each user/item pair
                phi[u, i, :] = np.exp(l) / np.sum(np.exp(l))
    
    print('Phi updated')
    
    ## Users (Theta) - Gamma Shape Update           
    for u in range(num_users):
        #print(u) if u %100 == 0 else None
        for d in range(k):
            k_sum = 0
            for i in range(num_items):
                k_sum += y_ui[u, i] * phi[u,i,d]
            gamma_shp[u,d] = a + k_sum
            #gamma_shpe[u, :] = a + (np.dot(y_ui[u, :], phi[u, :, :]))
            
    print('Users (Theta) - Gamma Shape Updated')
    
    ## Users (Theta) - Gamma Rate Update 
    for u in range(num_users):
        #print(u) if u %100 == 0 else None
        for d in range(k):
            k_sum = 0
            for i in range(num_items):
                k_sum += lambda_shp[i,d]/lambda_rte[i,d]
            gamma_rte[u,d] = k_shp[u] / k_rte[u] + k_sum
            
    print('Users (Theta) - Gamma Rate Updated')
    
    ## Users Activity - Gamma Rate Update 
    for u in range(num_users):
        #print(u) if u %100 == 0 else None
        k_sum = 0
        for d in range(k):
            k_sum += gamma_shp[u,d] / gamma_rte[u,d]
        k_rte[u] = a_prime / b_prime + k_sum
        
    print('Users Activity - Gamma Rate Updated')
    
    
    ## Items (Beta) - Gamma Shape Update  
    for i in range(num_items):
        #print(i) if i %100 == 0 else None
        for d in range(k):
            k_sum = 0
            for u in range(num_users):
                k_sum += y_ui[u, i] * phi[u,i,d]
            lambda_shp[i,d] = c + k_sum
            #gamma_shpe[u, :] = a + (np.dot(y_ui[u, :], phi[u, :, :]))
            
    print('Items (Beta) - Gamma Shape Updated')  
    
    ## Items (Beta) - Gamma Rate Update 
    for i in range(num_items):
        #print(i) if i %100 == 0 else None
        for d in range(k):
            k_sum = 0
            for u in range(num_users):
                k_sum += gamma_shp[u,d]/gamma_rte[u,d]
            lambda_rte[i,d] = t_shp[i] / t_rte[i] + k_sum
            
    print('Items (Beta) - Gamma Rate Updated')  

    ## Item Popularity - Gamma Rate Update 
    for i in range(num_items):
        #print(i) if i %100 == 0 else None
        k_sum = 0
        for d in range(k):
            k_sum += lambda_shp[i,d] / lambda_rte[i,d]
        t_rte[i] = c_prime / d_prime + k_sum
    
    print('Item Popularity - Gamma Rate Updated') 
    
    return gamma_shp, gamma_rte, lambda_shp, lambda_rte, k_shp, k_rte, t_shp, t_rte, phi

# %%
def CAVI(num_users, num_items, k, y_ui, gamma_shp, gamma_rte, lambda_shp, lambda_rte, k_shp, k_rte, t_shp, t_rte, phi):
    

    # Now we will update phi_uik with both shape and rate parameters inside the loop
    for u in range(num_users):
        #print(u) if u %100 == 0 else None
        for i in range(num_items):
            if y_ui[u, i] > 0:
                exponent = (digamma(gamma_shp[u,:]) - np.log(gamma_rte[u,:]) +
                            digamma(lambda_shp[i,:]) - np.log(lambda_rte[i,:]))
                    

                #print(l / np.sum(l))
                #print(np.exp(l) / np.sum(np.exp(l)))
                #print(np.sum(l))
                # Exponentiate and normalize phi_uik so that it sums to 1 over k for each user/item pair
                phi[u, i, :] = np.exp(exponent) / np.sum(np.exp(exponent))
    
    print('Phi updated')
    
    ## Users (Theta) - Gamma Shape Update           
    for u in range(num_users):
        #print(u) if u %100 == 0 else None
        for d in range(k):
            k_sum = y_ui[u, :] * phi[u,:,d]
            gamma_shp[u,d] = a + np.sum(k_sum)
            #gamma_shpe[u, :] = a + (np.dot(y_ui[u, :], phi[u, :, :]))
            
    print('Users (Theta) - Gamma Shape Updated')
    
    ## Users (Theta) - Gamma Rate Update 
    for u in range(num_users):
        #print(u) if u %100 == 0 else None
        for d in range(k):
            k_sum = lambda_shp[:,d]/lambda_rte[:,d]
            gamma_rte[u,d] = k_shp[u] / k_rte[u] + np.sum(k_sum)
            
    print('Users (Theta) - Gamma Rate Updated')
    
    ## Users Activity - Gamma Rate Update 
    for u in range(num_users):
        #print(u) if u %100 == 0 else None
        k_sum = 0
        for d in range(k):
            k_sum += gamma_shp[u,d] / gamma_rte[u,d]
        k_rte[u] = a_prime / b_prime + k_sum
        
    print('Users Activity - Gamma Rate Updated')
    
    
    ## Items (Beta) - Gamma Shape Update  
    for i in range(num_items):
        #print(i) if i %100 == 0 else None
        for d in range(k):
            k_sum = y_ui[:, i] * phi[:,i,d]
            lambda_shp[i,d] = c + np.sum(k_sum)
            #gamma_shpe[u, :] = a + (np.dot(y_ui[u, :], phi[u, :, :]))
            
    print('Items (Beta) - Gamma Shape Updated')  
    
    ## Items (Beta) - Gamma Rate Update 
    for i in range(num_items):
        #print(i) if i %100 == 0 else None
        for d in range(k):
            k_sum = gamma_shp[:,d]/gamma_rte[:,d]
            lambda_rte[i,d] = t_shp[i] / t_rte[i] + np.sum(k_sum)
            
    print('Items (Beta) - Gamma Rate Updated')  

    ## Item Popularity - Gamma Rate Update 
    for i in range(num_items):
        #print(i) if i %100 == 0 else None
        k_sum = 0
        for d in range(k):
            k_sum += lambda_shp[i,d] / lambda_rte[i,d]
        t_rte[i] = c_prime / d_prime + k_sum
    
    print('Item Popularity - Gamma Rate Updated') 
    
    return gamma_shp, gamma_rte, lambda_shp, lambda_rte, k_shp, k_rte, t_shp, t_rte, phi

# %%
def expectation(gamma_shp, gamma_rte, lambda_shp, lambda_rte, k, y_ui):
    
    num_users = y_ui.shape[0]
    num_items = y_ui.shape[1]
    
    ev_theta = np.empty((num_users,k))
    ev_beta = np.empty((num_items,k))
    for u in range(num_users):
        for d in range(k):
            ev_theta[u,d] = gamma_shp[u,d] / gamma_rte[u,d]

    for i in range(num_items):
        for d in range(k):
            ev_beta[i,d] = lambda_shp[i,d] / lambda_rte[i,d]
            
    return ev_theta, ev_beta

# %%
def log_likelihood(ev_theta, ev_beta, user_dict, item_dict, validation_set):
    likelihood_parameters = np.matmul(ev_theta, ev_beta.T)
    llk = 0
    for v in range(len(validation_set)):
        uu = validation_set['UserId'].iloc[v]
        ii = validation_set['ItemId'].iloc[v]
        u = user_dict[uu]
        i = item_dict[ii]
        value = validation_set['Count'].iloc[v]
        llk += - likelihood_parameters[u,i] - np.log(np.math.factorial(value)) + np.log(likelihood_parameters[u,i])*value
    return llk

# %%
i = 0
results = []
gamma_shp, gamma_rte, lambda_shp, lambda_rte, k_shp, k_rte, t_shp, t_rte, phi, a, a_prime, c, c_prime, b_prime, d_prime = initiliaze_parameters(y_ui.shape[0], y_ui.shape[1], k=5, a=0.3, a_prime=0.3, c=0.3, c_prime=0.3, b_prime=1.0, d_prime=1.0)
results.append(-np.inf)
while i < 500:
    print(f"Iteration {i}")
    start_time = time.time()
    
    
    gamma_shp, gamma_rte, lambda_shp, lambda_rte, k_shp, k_rte, t_shp, t_rte, phi = CAVI(y_ui.shape[0], y_ui.shape[1], 5, y_ui, gamma_shp, gamma_rte, lambda_shp, lambda_rte, k_shp, k_rte, t_shp, t_rte, phi)
    ev_theta, ev_beta = expectation(gamma_shp, gamma_rte, lambda_shp, lambda_rte, 5, y_ui)
    llk = log_likelihood(ev_theta, ev_beta, user_dict, item_dict, validation_set)
    print(llk)
    

    end_time = time.time()
    duration = end_time - start_time
    print(f"Iteration {i}: took {duration} seconds")
    
    results.append(llk)
    
    if ((results[-1] - results[-2])/ np.abs(results[-2])) < 0.000001:
        break
    i += 1
# Out:
# Iteration 0
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -265934.50152136013
# Iteration 0: took 7.3588080406188965 seconds
# Iteration 1
# /var/folders/7c/zq5pjc5156v6v5k591lqrbgc0000gp/T/ipykernel_13535/2737036036.py:22: RuntimeWarning: invalid value encountered in double_scalars
#   if ((results[-1] - results[-2])/ np.abs(results[-2])) < 0.000001:
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -264425.946124182
# Iteration 1: took 7.079814910888672 seconds
# Iteration 2
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -264424.25298697717
# Iteration 2: took 7.009635925292969 seconds
# Iteration 3
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -264413.56343885086
# Iteration 3: took 7.081421613693237 seconds
# Iteration 4
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -264395.49050597625
# Iteration 4: took 7.039902925491333 seconds
# Iteration 5
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -264362.8898645666
# Iteration 5: took 7.063109874725342 seconds
# Iteration 6
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -264300.83374376677
# Iteration 6: took 7.043358087539673 seconds
# Iteration 7
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -264178.18021959
# Iteration 7: took 7.0664660930633545 seconds
# Iteration 8
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -263930.7946989562
# Iteration 8: took 6.9766411781311035 seconds
# Iteration 9
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -263430.54368469265
# Iteration 9: took 7.072906017303467 seconds
# Iteration 10
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -262434.6994405372
# Iteration 10: took 7.033080101013184 seconds
# Iteration 11
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -260531.19529944428
# Iteration 11: took 6.992298126220703 seconds
# Iteration 12
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -257182.83850913274
# Iteration 12: took 7.065942049026489 seconds
# Iteration 13
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -252095.6258625586
# Iteration 13: took 7.0781028270721436 seconds
# Iteration 14
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -245865.15180483565
# Iteration 14: took 7.052037954330444 seconds
# Iteration 15
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -239949.88591665085
# Iteration 15: took 7.010859966278076 seconds
# Iteration 16
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -235462.15816420564
# Iteration 16: took 7.016539812088013 seconds
# Iteration 17
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -232471.64211989415
# Iteration 17: took 7.063424110412598 seconds
# Iteration 18
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -230496.28415845975
# Iteration 18: took 7.075833797454834 seconds
# Iteration 19
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -229044.69523085846
# Iteration 19: took 7.214662790298462 seconds
# Iteration 20
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -227860.77316633944
# Iteration 20: took 7.116350889205933 seconds
# Iteration 21
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -226873.32605270165
# Iteration 21: took 7.115714073181152 seconds
# Iteration 22
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -226058.98979881403
# Iteration 22: took 7.051385879516602 seconds
# Iteration 23
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -225398.96543687565
# Iteration 23: took 7.054116249084473 seconds
# Iteration 24
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -224877.40394225324
# Iteration 24: took 7.0621960163116455 seconds
# Iteration 25
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -224464.4214572168
# Iteration 25: took 7.036043882369995 seconds
# Iteration 26
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -224139.85151179638
# Iteration 26: took 7.028263807296753 seconds
# Iteration 27
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -223885.71433118742
# Iteration 27: took 7.040470123291016 seconds
# Iteration 28
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -223668.07355112483
# Iteration 28: took 7.003483295440674 seconds
# Iteration 29
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -223492.30469097782
# Iteration 29: took 7.01961088180542 seconds
# Iteration 30
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -223354.47442505707
# Iteration 30: took 6.947407007217407 seconds
# Iteration 31
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -223236.4093985016
# Iteration 31: took 7.024785995483398 seconds
# Iteration 32
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -223142.82516110802
# Iteration 32: took 6.97472882270813 seconds
# Iteration 33
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -223062.93254586935
# Iteration 33: took 6.992274761199951 seconds
# Iteration 34
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222990.28745881194
# Iteration 34: took 7.031030178070068 seconds
# Iteration 35
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222921.73085253403
# Iteration 35: took 6.980959177017212 seconds
# Iteration 36
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222855.87473122712
# Iteration 36: took 6.918448209762573 seconds
# Iteration 37
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222792.42522406508
# Iteration 37: took 7.061521768569946 seconds
# Iteration 38
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222731.2499179419
# Iteration 38: took 7.115607023239136 seconds
# Iteration 39
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222671.8998057173
# Iteration 39: took 7.014366149902344 seconds
# Iteration 40
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222613.91808451
# Iteration 40: took 6.968727111816406 seconds
# Iteration 41
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222557.06473021174
# Iteration 41: took 7.0578320026397705 seconds
# Iteration 42
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222501.2780876205
# Iteration 42: took 7.163945913314819 seconds
# Iteration 43
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222446.58385405684
# Iteration 43: took 8.050988912582397 seconds
# Iteration 44
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222393.031100471
# Iteration 44: took 7.239709138870239 seconds
# Iteration 45
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222340.66878302174
# Iteration 45: took 7.141562223434448 seconds
# Iteration 46
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222289.53545447762
# Iteration 46: took 8.107687950134277 seconds
# Iteration 47
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222239.84861227206
# Iteration 47: took 7.135298013687134 seconds
# Iteration 48
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222191.99096746653
# Iteration 48: took 7.138012886047363 seconds
# Iteration 49
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222146.18230006835
# Iteration 49: took 7.036494016647339 seconds
# Iteration 50
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222102.2981425131
# Iteration 50: took 7.016221046447754 seconds
# Iteration 51
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222059.91061090666
# Iteration 51: took 7.0080907344818115 seconds
# Iteration 52
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -222018.45688247596
# Iteration 52: took 6.970915794372559 seconds
# Iteration 53
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221977.51824225282
# Iteration 53: took 7.1421589851379395 seconds
# Iteration 54
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221937.01165696475
# Iteration 54: took 7.219567775726318 seconds
# Iteration 55
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221897.0218228813
# Iteration 55: took 7.049048900604248 seconds
# Iteration 56
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221857.6275006984
# Iteration 56: took 7.014478921890259 seconds
# Iteration 57
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221818.99194876285
# Iteration 57: took 7.174468040466309 seconds
# Iteration 58
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221781.36608232404
# Iteration 58: took 6.9963109493255615 seconds
# Iteration 59
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221744.9003853843
# Iteration 59: took 7.090692758560181 seconds
# Iteration 60
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221709.55333923627
# Iteration 60: took 6.942007064819336 seconds
# Iteration 61
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221675.2005019619
# Iteration 61: took 7.018250942230225 seconds
# Iteration 62
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221641.7802535177
# Iteration 62: took 6.9731879234313965 seconds
# Iteration 63
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221609.34298028774
# Iteration 63: took 7.445796012878418 seconds
# Iteration 64
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221577.98092120912
# Iteration 64: took 7.634968996047974 seconds
# Iteration 65
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221547.6962805476
# Iteration 65: took 7.0386292934417725 seconds
# Iteration 66
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221518.32261923098
# Iteration 66: took 7.030339002609253 seconds
# Iteration 67
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221489.5543215485
# Iteration 67: took 7.119502067565918 seconds
# Iteration 68
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221461.05220431602
# Iteration 68: took 7.0849609375 seconds
# Iteration 69
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221432.56585570343
# Iteration 69: took 7.189750671386719 seconds
# Iteration 70
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221404.02221171517
# Iteration 70: took 7.12990403175354 seconds
# Iteration 71
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221375.54305754538
# Iteration 71: took 6.965017080307007 seconds
# Iteration 72
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221347.3898313315
# Iteration 72: took 7.041622161865234 seconds
# Iteration 73
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221319.85249112663
# Iteration 73: took 6.977318048477173 seconds
# Iteration 74
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221293.1506741386
# Iteration 74: took 6.973920106887817 seconds
# Iteration 75
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221267.41402392284
# Iteration 75: took 7.035195827484131 seconds
# Iteration 76
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221242.70757541258
# Iteration 76: took 6.927135944366455 seconds
# Iteration 77
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221219.03509076344
# Iteration 77: took 6.986525297164917 seconds
# Iteration 78
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221196.32259160778
# Iteration 78: took 6.939770221710205 seconds
# Iteration 79
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221174.4282509534
# Iteration 79: took 7.000050067901611 seconds
# Iteration 80
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221153.17801890886
# Iteration 80: took 6.927037239074707 seconds
# Iteration 81
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221132.3837511121
# Iteration 81: took 6.9348061084747314 seconds
# Iteration 82
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221111.83279977288
# Iteration 82: took 7.011113882064819 seconds
# Iteration 83
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221091.29113744112
# Iteration 83: took 7.065131902694702 seconds
# Iteration 84
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221070.5438238159
# Iteration 84: took 6.99980616569519 seconds
# Iteration 85
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221049.4316914474
# Iteration 85: took 6.993396997451782 seconds
# Iteration 86
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221027.86067827267
# Iteration 86: took 7.02866005897522 seconds
# Iteration 87
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -221005.809377838
# Iteration 87: took 7.033643960952759 seconds
# Iteration 88
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220983.33104691902
# Iteration 88: took 7.124636888504028 seconds
# Iteration 89
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220960.51948624733
# Iteration 89: took 7.038691997528076 seconds
# Iteration 90
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220937.4509486708
# Iteration 90: took 7.05209493637085 seconds
# Iteration 91
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220914.14728363958
# Iteration 91: took 7.032124996185303 seconds
# Iteration 92
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220890.57838223758
# Iteration 92: took 6.971312999725342 seconds
# Iteration 93
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220866.69068796557
# Iteration 93: took 6.995991945266724 seconds
# Iteration 94
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220842.44287702694
# Iteration 94: took 6.980093955993652 seconds
# Iteration 95
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220817.82779967107
# Iteration 95: took 7.034960985183716 seconds
# Iteration 96
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220792.86439802105
# Iteration 96: took 6.985252141952515 seconds
# Iteration 97
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220767.5579685482
# Iteration 97: took 6.983508348464966 seconds
# Iteration 98
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220741.8570913441
# Iteration 98: took 7.016201972961426 seconds
# Iteration 99
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220715.63902386127
# Iteration 99: took 6.963475942611694 seconds
# Iteration 100
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220688.7266867817
# Iteration 100: took 7.019355058670044 seconds
# Iteration 101
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220660.93489124568
# Iteration 101: took 7.173713207244873 seconds
# Iteration 102
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220632.15210400635
# Iteration 102: took 7.014379978179932 seconds
# Iteration 103
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220602.411026004
# Iteration 103: took 6.986171007156372 seconds
# Iteration 104
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220571.863632663
# Iteration 104: took 7.0171263217926025 seconds
# Iteration 105
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220540.69367725152
# Iteration 105: took 6.993051052093506 seconds
# Iteration 106
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220509.1266364618
# Iteration 106: took 6.961289167404175 seconds
# Iteration 107
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220477.54786886368
# Iteration 107: took 7.00941801071167 seconds
# Iteration 108
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220446.55310392258
# Iteration 108: took 6.97662091255188 seconds
# Iteration 109
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220416.8643191808
# Iteration 109: took 7.03744101524353 seconds
# Iteration 110
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220389.13350573456
# Iteration 110: took 7.0016138553619385 seconds
# Iteration 111
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220363.7055640519
# Iteration 111: took 6.990736246109009 seconds
# Iteration 112
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220340.50890694777
# Iteration 112: took 6.9843971729278564 seconds
# Iteration 113
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220319.1559138826
# Iteration 113: took 7.003239870071411 seconds
# Iteration 114
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220299.15663687818
# Iteration 114: took 7.031856298446655 seconds
# Iteration 115
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220280.0854260508
# Iteration 115: took 7.073506832122803 seconds
# Iteration 116
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220261.62982412393
# Iteration 116: took 7.033601999282837 seconds
# Iteration 117
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220243.54065424312
# Iteration 117: took 7.062387943267822 seconds
# Iteration 118
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220225.56033990424
# Iteration 118: took 7.126774072647095 seconds
# Iteration 119
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220207.43143083167
# Iteration 119: took 7.044215202331543 seconds
# Iteration 120
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220189.00541670353
# Iteration 120: took 7.06218695640564 seconds
# Iteration 121
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220170.3442261054
# Iteration 121: took 7.045264959335327 seconds
# Iteration 122
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220151.69946594816
# Iteration 122: took 7.016592741012573 seconds
# Iteration 123
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220133.3782652372
# Iteration 123: took 7.085798025131226 seconds
# Iteration 124
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220115.6177674748
# Iteration 124: took 6.994582891464233 seconds
# Iteration 125
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220098.55722970364
# Iteration 125: took 6.9790263175964355 seconds
# Iteration 126
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220082.26128628483
# Iteration 126: took 7.004582166671753 seconds
# Iteration 127
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220066.71629203352
# Iteration 127: took 7.086599826812744 seconds
# Iteration 128
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220051.81361443957
# Iteration 128: took 7.0811238288879395 seconds
# Iteration 129
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220037.36701976953
# Iteration 129: took 7.111433982849121 seconds
# Iteration 130
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220023.16197280242
# Iteration 130: took 7.015249967575073 seconds
# Iteration 131
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -220009.01271466748
# Iteration 131: took 7.078303813934326 seconds
# Iteration 132
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219994.81503516802
# Iteration 132: took 7.041424989700317 seconds
# Iteration 133
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219980.5844082181
# Iteration 133: took 7.030084848403931 seconds
# Iteration 134
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219966.4646225278
# Iteration 134: took 6.99864387512207 seconds
# Iteration 135
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219952.6921837923
# Iteration 135: took 7.06379508972168 seconds
# Iteration 136
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219939.5236052854
# Iteration 136: took 7.0436742305755615 seconds
# Iteration 137
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219927.15093937973
# Iteration 137: took 7.017391681671143 seconds
# Iteration 138
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219915.64315256473
# Iteration 138: took 7.047504901885986 seconds
# Iteration 139
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219904.9471684208
# Iteration 139: took 7.033038854598999 seconds
# Iteration 140
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219894.94423916037
# Iteration 140: took 7.056236982345581 seconds
# Iteration 141
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219885.52143405585
# Iteration 141: took 7.043942928314209 seconds
# Iteration 142
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219876.61805433768
# Iteration 142: took 7.022817850112915 seconds
# Iteration 143
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219868.22884049482
# Iteration 143: took 7.036396026611328 seconds
# Iteration 144
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219860.37104818062
# Iteration 144: took 7.193498849868774 seconds
# Iteration 145
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219853.0407000862
# Iteration 145: took 7.0679030418396 seconds
# Iteration 146
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219846.18269237436
# Iteration 146: took 7.05953574180603 seconds
# Iteration 147
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219839.69125374357
# Iteration 147: took 7.014906883239746 seconds
# Iteration 148
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219833.4425428947
# Iteration 148: took 7.079326152801514 seconds
# Iteration 149
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219827.3398130053
# Iteration 149: took 7.023135185241699 seconds
# Iteration 150
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219821.34134620626
# Iteration 150: took 7.01569676399231 seconds
# Iteration 151
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219815.45382148586
# Iteration 151: took 7.0281970500946045 seconds
# Iteration 152
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219809.69903427662
# Iteration 152: took 7.021351099014282 seconds
# Iteration 153
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219804.07753199406
# Iteration 153: took 7.094739198684692 seconds
# Iteration 154
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219798.55104677498
# Iteration 154: took 7.064974784851074 seconds
# Iteration 155
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219793.05000825753
# Iteration 155: took 7.031145334243774 seconds
# Iteration 156
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219787.49471010742
# Iteration 156: took 7.039464950561523 seconds
# Iteration 157
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# ...
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219708.21947841014
# Iteration 172: took 6.941744089126587 seconds
# Iteration 173
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219706.26452318483
# Iteration 173: took 7.10425329208374 seconds
# Iteration 174
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219704.56089485693
# Iteration 174: took 7.033150911331177 seconds
# Iteration 175
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219703.0579465576
# Iteration 175: took 6.9899609088897705 seconds
# Iteration 176
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219701.69397778146
# Iteration 176: took 6.978801965713501 seconds
# Iteration 177
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219700.3962394582
# Iteration 177: took 7.025091171264648 seconds
# Iteration 178
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219699.08935725325
# Iteration 178: took 7.041247844696045 seconds
# Iteration 179
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219697.7076961179
# Iteration 179: took 6.967026233673096 seconds
# Iteration 180
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219696.20759577642
# Iteration 180: took 6.984165191650391 seconds
# Iteration 181
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219694.57492198216
# Iteration 181: took 7.033401966094971 seconds
# Iteration 182
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219692.8247156514
# Iteration 182: took 6.9615278244018555 seconds
# Iteration 183
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219690.99336505771
# Iteration 183: took 6.990322828292847 seconds
# Iteration 184
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219689.12686842505
# Iteration 184: took 7.0233988761901855 seconds
# Iteration 185
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219687.27054725948
# Iteration 185: took 6.983098983764648 seconds
# Iteration 186
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219685.46332082694
# Iteration 186: took 6.958530902862549 seconds
# Iteration 187
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219683.7340544841
# Iteration 187: took 6.982589960098267 seconds
# Iteration 188
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219682.09811374632
# Iteration 188: took 7.0020647048950195 seconds
# Iteration 189
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219680.5546263544
# Iteration 189: took 7.004685163497925 seconds
# Iteration 190
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219679.08439747716
# Iteration 190: took 6.975660085678101 seconds
# Iteration 191
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219677.64941027478
# Iteration 191: took 6.974230766296387 seconds
# Iteration 192
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219676.196755988
# Iteration 192: took 6.9265830516815186 seconds
# Iteration 193
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219674.6694068797
# Iteration 193: took 6.9614667892456055 seconds
# Iteration 194
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219673.0233615542
# Iteration 194: took 6.940486907958984 seconds
# Iteration 195
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219671.245865224
# Iteration 195: took 6.954023361206055 seconds
# Iteration 196
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219669.36518440378
# Iteration 196: took 6.999360084533691 seconds
# Iteration 197
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219667.44409674185
# Iteration 197: took 6.9575440883636475 seconds
# Iteration 198
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219665.55885353097
# Iteration 198: took 7.013941764831543 seconds
# Iteration 199
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219663.77571668007
# Iteration 199: took 6.973197937011719 seconds
# Iteration 200
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219662.13799797528
# Iteration 200: took 6.988940954208374 seconds
# Iteration 201
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219660.66648037403
# Iteration 201: took 6.970131874084473 seconds
# Iteration 202
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219659.36639575465
# Iteration 202: took 6.960285186767578 seconds
# Iteration 203
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219658.23379996014
# Iteration 203: took 6.942436933517456 seconds
# Iteration 204
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219657.25843643115
# Iteration 204: took 7.005589962005615 seconds
# Iteration 205
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219656.4234819212
# Iteration 205: took 6.951756954193115 seconds
# Iteration 206
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219655.70403054808
# Iteration 206: took 6.953189849853516 seconds
# Iteration 207
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219655.06600657673
# Iteration 207: took 7.106092691421509 seconds
# Iteration 208
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219654.4664716119
# Iteration 208: took 7.031821966171265 seconds
# Iteration 209
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219653.8559248496
# Iteration 209: took 7.0772459506988525 seconds
# Iteration 210
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219653.18300143667
# Iteration 210: took 7.030939102172852 seconds
# Iteration 211
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219652.40155836908
# Iteration 211: took 7.01940393447876 seconds
# Iteration 212
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219651.4793053403
# Iteration 212: took 7.0051960945129395 seconds
# Iteration 213
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219650.40604709723
# Iteration 213: took 6.950342893600464 seconds
# Iteration 214
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219649.19898032985
# Iteration 214: took 7.005397796630859 seconds
# Iteration 215
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219647.90263428193
# Iteration 215: took 6.965395212173462 seconds
# Iteration 216
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219646.58184736146
# Iteration 216: took 6.997733116149902 seconds
# Iteration 217
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219645.30848607278
# Iteration 217: took 7.0075929164886475 seconds
# Iteration 218
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219644.14619807
# Iteration 218: took 7.032405853271484 seconds
# Iteration 219
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219643.13916757738
# Iteration 219: took 6.940016984939575 seconds
# Iteration 220
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219642.30860451199
# Iteration 220: took 6.889918088912964 seconds
# Iteration 221
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219641.65635922874
# Iteration 221: took 6.996728181838989 seconds
# Iteration 222
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219641.17158919934
# Iteration 222: took 6.983524799346924 seconds
# Iteration 223
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219640.8361385781
# Iteration 223: took 6.9663920402526855 seconds
# Iteration 224
# Phi updated
# Users (Theta) - Gamma Shape Updated
# Users (Theta) - Gamma Rate Updated
# Users Activity - Gamma Rate Updated
# Items (Beta) - Gamma Shape Updated
# Items (Beta) - Gamma Rate Updated
# Item Popularity - Gamma Rate Updated
# -219640.62702372795
# Iteration 224: took 7.056410312652588 seconds

# %%
results
# Out:
# [-inf,
#  -265934.50152136013,
#  -264425.946124182,
#  -264424.25298697717,
#  -264413.56343885086,
#  -264395.49050597625,
#  -264362.8898645666,
#  -264300.83374376677,
#  -264178.18021959,
#  -263930.7946989562,
#  -263430.54368469265,
#  -262434.6994405372,
#  -260531.19529944428,
#  -257182.83850913274,
#  -252095.6258625586,
#  -245865.15180483565,
#  -239949.88591665085,
#  -235462.15816420564,
#  -232471.64211989415,
#  -230496.28415845975,
#  -229044.69523085846,
#  -227860.77316633944,
#  -226873.32605270165,
#  -226058.98979881403,
#  -225398.96543687565,
#  -224877.40394225324,
#  -224464.4214572168,
#  -224139.85151179638,
#  -223885.71433118742,
#  -223668.07355112483,
#  -223492.30469097782,
#  -223354.47442505707,
#  -223236.4093985016,
#  -223142.82516110802,
#  -223062.93254586935,
#  -222990.28745881194,
#  -222921.73085253403,
#  -222855.87473122712,
#  -222792.42522406508,
#  -222731.2499179419,
#  -222671.8998057173,
#  -222613.91808451,
#  -222557.06473021174,
#  -222501.2780876205,
#  -222446.58385405684,
#  -222393.031100471,
#  -222340.66878302174,
#  -222289.53545447762,
#  -222239.84861227206,
#  -222191.99096746653,
#  -222146.18230006835,
#  -222102.2981425131,
#  -222059.91061090666,
#  -222018.45688247596,
#  -221977.51824225282,
#  -221937.01165696475,
#  -221897.0218228813,
#  -221857.6275006984,
#  -221818.99194876285,
#  -221781.36608232404,
#  -221744.9003853843,
#  -221709.55333923627,
#  -221675.2005019619,
#  -221641.7802535177,
#  -221609.34298028774,
#  -221577.98092120912,
#  -221547.6962805476,
#  -221518.32261923098,
#  -221489.5543215485,
#  -221461.05220431602,
#  -221432.56585570343,
#  -221404.02221171517,
#  -221375.54305754538,
#  -221347.3898313315,
#  -221319.85249112663,
#  -221293.1506741386,
#  -221267.41402392284,
#  -221242.70757541258,
#  -221219.03509076344,
#  -221196.32259160778,
#  -221174.4282509534,
#  -221153.17801890886,
#  -221132.3837511121,
#  -221111.83279977288,
#  -221091.29113744112,
#  -221070.5438238159,
#  -221049.4316914474,
#  -221027.86067827267,
#  -221005.809377838,
#  -220983.33104691902,
#  -220960.51948624733,
#  -220937.4509486708,
#  -220914.14728363958,
#  -220890.57838223758,
#  -220866.69068796557,
#  -220842.44287702694,
#  -220817.82779967107,
#  -220792.86439802105,
#  -220767.5579685482,
#  -220741.8570913441,
#  -220715.63902386127,
#  -220688.7266867817,
#  -220660.93489124568,
#  -220632.15210400635,
#  -220602.411026004,
#  -220571.863632663,
#  -220540.69367725152,
#  -220509.1266364618,
#  -220477.54786886368,
#  -220446.55310392258,
#  -220416.8643191808,
#  -220389.13350573456,
#  -220363.7055640519,
#  -220340.50890694777,
#  -220319.1559138826,
#  -220299.15663687818,
#  -220280.0854260508,
#  -220261.62982412393,
#  -220243.54065424312,
#  -220225.56033990424,
#  -220207.43143083167,
#  -220189.00541670353,
#  -220170.3442261054,
#  -220151.69946594816,
#  -220133.3782652372,
#  -220115.6177674748,
#  -220098.55722970364,
#  -220082.26128628483,
#  -220066.71629203352,
#  -220051.81361443957,
#  -220037.36701976953,
#  -220023.16197280242,
#  -220009.01271466748,
#  -219994.81503516802,
#  -219980.5844082181,
#  -219966.4646225278,
#  -219952.6921837923,
#  -219939.5236052854,
#  -219927.15093937973,
#  -219915.64315256473,
#  -219904.9471684208,
#  -219894.94423916037,
#  -219885.52143405585,
#  -219876.61805433768,
#  -219868.22884049482,
#  -219860.37104818062,
#  -219853.0407000862,
#  -219846.18269237436,
#  -219839.69125374357,
#  -219833.4425428947,
#  -219827.3398130053,
#  -219821.34134620626,
#  -219815.45382148586,
#  -219809.69903427662,
#  -219804.07753199406,
#  -219798.55104677498,
#  -219793.05000825753,
#  -219787.49471010742,
#  -219781.81583598594,
#  -219775.96992470682,
#  -219769.94983494922,
#  -219763.78768485447,
#  -219757.54880547323,
#  -219751.32082128097,
#  -219745.20343651914,
#  -219739.30096903862,
#  -219733.71751355915,
#  -219728.55125413786,
#  -219723.88182443284,
#  -219719.75482242848,
#  -219716.17405351743,
#  -219713.10346814952,
#  -219710.4772499075,
#  -219708.21947841014,
#  -219706.26452318483,
#  -219704.56089485693,
#  -219703.0579465576,
#  -219701.69397778146,
#  -219700.3962394582,
#  -219699.08935725325,
#  -219697.7076961179,
#  -219696.20759577642,
#  -219694.57492198216,
#  -219692.8247156514,
#  -219690.99336505771,
#  -219689.12686842505,
#  -219687.27054725948,
#  -219685.46332082694,
#  -219683.7340544841,
#  -219682.09811374632,
#  -219680.5546263544,
#  -219679.08439747716,
#  -219677.64941027478,
#  -219676.196755988,
#  -219674.6694068797,
#  -219673.0233615542,
#  -219671.245865224,
#  -219669.36518440378,
#  -219667.44409674185,
#  -219665.55885353097,
#  -219663.77571668007,
#  -219662.13799797528,
#  -219660.66648037403,
#  -219659.36639575465,
#  -219658.23379996014,
#  -219657.25843643115,
#  -219656.4234819212,
#  -219655.70403054808,
#  -219655.06600657673,
#  -219654.4664716119,
#  -219653.8559248496,
#  -219653.18300143667,
#  -219652.40155836908,
#  -219651.4793053403,
#  -219650.40604709723,
#  -219649.19898032985,
#  -219647.90263428193,
#  -219646.58184736146,
#  -219645.30848607278,
#  -219644.14619807,
#  -219643.13916757738,
#  -219642.30860451199,
#  -219641.65635922874,
#  -219641.17158919934,
#  -219640.8361385781,
#  -219640.62702372795]

# %%
np.save('gamma_shp.npy', gamma_shp)  
np.save('gamma_rte.npy', gamma_rte)  
np.save('lambda_shp.npy', lambda_shp)  
np.save('lambda_rte.npy', lambda_rte)  
np.save('k_shp.npy', k_shp)  
np.save('k_rte.npy', k_rte)  
np.save('t_shp.npy', t_shp)  
np.save('t_rte.npy', t_rte)  
np.save('phi.npy', phi)

# %%
import numpy as np

gamma_shp = np.load('gamma_shp.npy')
gamma_rte = np.load('gamma_rte.npy')
lambda_shp = np.load('lambda_shp.npy')
lambda_rte = np.load('lambda_rte.npy')
k_shp = np.load('k_shp.npy')
k_rte = np.load('k_rte.npy')
t_shp = np.load('t_shp.npy')
t_rte = np.load('t_rte.npy')
phi = np.load('phi.npy')

# %% [markdown]
# # Prediction
